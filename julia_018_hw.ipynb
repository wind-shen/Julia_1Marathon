# %% [markdown]
# # DataFrames.jl 介紹 (二): Joins 與 Split-Apply-Combine Strategy
#
# ## Day 018 作業1：The Split-Apply-Combine Strategy
#
# 同 Day 017，請載入 2020/4/2 COVID-19 Daily Report 資料集，計算每個國家/地區的累計確診人數，並列出所有資料筆數。

# %%
using DataFrames, CSV

# %%
df = CSV.read("04-02-2020.csv")
# Out:
# 2569×12 DataFrame. Omitted printing of 8 columns
# │ Row  │ FIPS    │ Admin2     │ Province_State │ Country_Region       │
# │      │ Int64⍰  │ String⍰    │ String⍰        │ String               │
# ├──────┼─────────┼────────────┼────────────────┼──────────────────────┤
# │ 1    │ 45001   │ Abbeville  │ South Carolina │ US                   │
# │ 2    │ 22001   │ Acadia     │ Louisiana      │ US                   │
# │ 3    │ 51001   │ Accomack   │ Virginia       │ US                   │
# │ 4    │ 16001   │ Ada        │ Idaho          │ US                   │
# │ 5    │ 19001   │ Adair      │ Iowa           │ US                   │
# │ 6    │ 29001   │ Adair      │ Missouri       │ US                   │
# │ 7    │ 40001   │ Adair      │ Oklahoma       │ US                   │
# │ 8    │ 8001    │ Adams      │ Colorado       │ US                   │
# │ 9    │ 16003   │ Adams      │ Idaho          │ US                   │
# │ 10   │ 17001   │ Adams      │ Illinois       │ US                   │
# ⋮
# │ 2559 │ missing │ missing    │ missing        │ Ukraine              │
# │ 2560 │ missing │ missing    │ missing        │ United Arab Emirates │
# │ 2561 │ missing │ missing    │ missing        │ United Kingdom       │
# │ 2562 │ missing │ missing    │ missing        │ Uruguay              │
# │ 2563 │ missing │ missing    │ missing        │ Uzbekistan           │
# │ 2564 │ missing │ missing    │ missing        │ Venezuela            │
# │ 2565 │ missing │ missing    │ missing        │ Vietnam              │
# │ 2566 │ missing │ missing    │ missing        │ West Bank and Gaza   │
# │ 2567 │ missing │ missing    │ missing        │ Zambia               │
# │ 2568 │ missing │ missing    │ missing        │ Zimbabwe             │
# │ 2569 │ missing │ unassigned │ Wyoming        │ US                   │

# %% [markdown]
# 計算計算每個國家/地區的累計確診人數
#
# 【提示】可使用 groupby 相關的函式

# %%
names(df)
# Out:
# 12-element Array{Symbol,1}:
#  :FIPS
#  :Admin2
#  :Province_State
#  :Country_Region
#  :Last_Update
#  :Lat
#  :Long_
#  :Confirmed
#  :Deaths
#  :Recovered
#  :Active
#  :Combined_Key

# %%
df2=by(df, :Country_Region, (:Province_State => length, :Confirmed  => sum))
# Out:
# 181×3 DataFrame
# │ Row │ Country_Region       │ Province_State_length │ Confirmed_sum │
# │     │ String               │ Int64                 │ Int64         │
# ├─────┼──────────────────────┼───────────────────────┼───────────────┤
# │ 1   │ US                   │ 2312                  │ 243599        │
# │ 2   │ Canada               │ 15                    │ 11284         │
# │ 3   │ United Kingdom       │ 10                    │ 34173         │
# │ 4   │ China                │ 33                    │ 82432         │
# │ 5   │ Netherlands          │ 5                     │ 14788         │
# │ 6   │ Australia            │ 8                     │ 5116          │
# │ 7   │ Denmark              │ 3                     │ 3573          │
# │ 8   │ France               │ 10                    │ 59929         │
# │ 9   │ Afghanistan          │ 1                     │ 273           │
# │ 10  │ Albania              │ 1                     │ 277           │
# ⋮
# │ 171 │ Turkey               │ 1                     │ 18135         │
# │ 172 │ Uganda               │ 1                     │ 45            │
# │ 173 │ Ukraine              │ 1                     │ 897           │
# │ 174 │ United Arab Emirates │ 1                     │ 1024          │
# │ 175 │ Uruguay              │ 1                     │ 350           │
# │ 176 │ Uzbekistan           │ 1                     │ 205           │
# │ 177 │ Venezuela            │ 1                     │ 146           │
# │ 178 │ Vietnam              │ 1                     │ 233           │
# │ 179 │ West Bank and Gaza   │ 1                     │ 161           │
# │ 180 │ Zambia               │ 1                     │ 39            │
# │ 181 │ Zimbabwe             │ 1                     │ 9             │

# %%
# 顯示所有資料
show(df2, allcols=true, allrows=true)
# Out:
# 181×3 DataFrame
# │ Row │ Country_Region                   │ Province_State_length │
# │     │ String                           │ Int64                 │
# ├─────┼──────────────────────────────────┼───────────────────────┤
# │ 1   │ US                               │ 2312                  │
# │ 2   │ Canada                           │ 15                    │
# │ 3   │ United Kingdom                   │ 10                    │
# │ 4   │ China                            │ 33                    │
# │ 5   │ Netherlands                      │ 5                     │
# │ 6   │ Australia                        │ 8                     │
# │ 7   │ Denmark                          │ 3                     │
# │ 8   │ France                           │ 10                    │
# │ 9   │ Afghanistan                      │ 1                     │
# │ 10  │ Albania                          │ 1                     │
# │ 11  │ Algeria                          │ 1                     │
# │ 12  │ Andorra                          │ 1                     │
# │ 13  │ Angola                           │ 1                     │
# │ 14  │ Antigua and Barbuda              │ 1                     │
# │ 15  │ Argentina                        │ 1                     │
# │ 16  │ Armenia                          │ 1                     │
# │ 17  │ Austria                          │ 1                     │
# │ 18  │ Azerbaijan                       │ 1                     │
# │ 19  │ Bahamas                          │ 1                     │
# │ 20  │ Bahrain                          │ 1                     │
# │ 21  │ Bangladesh                       │ 1                     │
# │ 22  │ Barbados                         │ 1                     │
# │ 23  │ Belarus                          │ 1                     │
# │ 24  │ Belgium                          │ 1                     │
# │ 25  │ Belize                           │ 1                     │
# │ 26  │ Benin                            │ 1                     │
# │ 27  │ Bhutan                           │ 1                     │
# │ 28  │ Bolivia                          │ 1                     │
# │ 29  │ Bosnia and Herzegovina           │ 1                     │
# │ 30  │ Botswana                         │ 1                     │
# │ 31  │ Brazil                           │ 1                     │
# │ 32  │ Brunei                           │ 1                     │
# │ 33  │ Bulgaria                         │ 1                     │
# │ 34  │ Burkina Faso                     │ 1                     │
# │ 35  │ Burma                            │ 1                     │
# │ 36  │ Burundi                          │ 1                     │
# │ 37  │ Cabo Verde                       │ 1                     │
# │ 38  │ Cambodia                         │ 1                     │
# │ 39  │ Cameroon                         │ 1                     │
# │ 40  │ Central African Republic         │ 1                     │
# │ 41  │ Chad                             │ 1                     │
# │ 42  │ Chile                            │ 1                     │
# │ 43  │ Colombia                         │ 1                     │
# │ 44  │ Congo (Brazzaville)              │ 1                     │
# │ 45  │ Congo (Kinshasa)                 │ 1                     │
# │ 46  │ Costa Rica                       │ 1                     │
# │ 47  │ Cote d'Ivoire                    │ 1                     │
# │ 48  │ Croatia                          │ 1                     │
# │ 49  │ Cuba                             │ 1                     │
# │ 50  │ Cyprus                           │ 1                     │
# │ 51  │ Czechia                          │ 1                     │
# │ 52  │ Diamond Princess                 │ 1                     │
# │ 53  │ Djibouti                         │ 1                     │
# │ 54  │ Dominica                         │ 1                     │
# │ 55  │ Dominican Republic               │ 1                     │
# │ 56  │ Ecuador                          │ 1                     │
# │ 57  │ Egypt                            │ 1                     │
# │ 58  │ El Salvador                      │ 1                     │
# │ 59  │ Equatorial Guinea                │ 1                     │
# │ 60  │ Eritrea                          │ 1                     │
# │ 61  │ Estonia                          │ 1                     │
# │ 62  │ Eswatini                         │ 1                     │
# │ 63  │ Ethiopia                         │ 1                     │
# │ 64  │ Fiji                             │ 1                     │
# │ 65  │ Finland                          │ 1                     │
# │ 66  │ Gabon                            │ 1                     │
# │ 67  │ Gambia                           │ 1                     │
# │ 68  │ Georgia                          │ 1                     │
# │ 69  │ Germany                          │ 1                     │
# │ 70  │ Ghana                            │ 1                     │
# │ 71  │ Greece                           │ 1                     │
# │ 72  │ Grenada                          │ 1                     │
# │ 73  │ Guatemala                        │ 1                     │
# │ 74  │ Guinea                           │ 1                     │
# │ 75  │ Guinea-Bissau                    │ 1                     │
# │ 76  │ Guyana                           │ 1                     │
# │ 77  │ Haiti                            │ 1                     │
# │ 78  │ Holy See                         │ 1                     │
# │ 79  │ Honduras                         │ 1                     │
# │ 80  │ Hungary                          │ 1                     │
# │ 81  │ Iceland                          │ 1                     │
# │ 82  │ India                            │ 1                     │
# │ 83  │ Indonesia                        │ 1                     │
# │ 84  │ Iran                             │ 1                     │
# │ 85  │ Iraq                             │ 1                     │
# │ 86  │ Ireland                          │ 1                     │
# │ 87  │ Israel                           │ 1                     │
# │ 88  │ Italy                            │ 1                     │
# │ 89  │ Jamaica                          │ 1                     │
# │ 90  │ Japan                            │ 1                     │
# │ 91  │ Jordan                           │ 1                     │
# │ 92  │ Kazakhstan                       │ 1                     │
# │ 93  │ Kenya                            │ 1                     │
# │ 94  │ Korea, South                     │ 1                     │
# │ 95  │ Kosovo                           │ 1                     │
# │ 96  │ Kuwait                           │ 1                     │
# │ 97  │ Kyrgyzstan                       │ 1                     │
# │ 98  │ Laos                             │ 1                     │
# │ 99  │ Latvia                           │ 1                     │
# │ 100 │ Lebanon                          │ 1                     │
# │ 101 │ Liberia                          │ 1                     │
# │ 102 │ Libya                            │ 1                     │
# │ 103 │ Liechtenstein                    │ 1                     │
# │ 104 │ Lithuania                        │ 1                     │
# │ 105 │ Luxembourg                       │ 1                     │
# │ 106 │ MS Zaandam                       │ 1                     │
# │ 107 │ Madagascar                       │ 1                     │
# │ 108 │ Malawi                           │ 1                     │
# │ 109 │ Malaysia                         │ 1                     │
# │ 110 │ Maldives                         │ 1                     │
# │ 111 │ Mali                             │ 1                     │
# │ 112 │ Malta                            │ 1                     │
# │ 113 │ Mauritania                       │ 1                     │
# │ 114 │ Mauritius                        │ 1                     │
# │ 115 │ Mexico                           │ 1                     │
# │ 116 │ Moldova                          │ 1                     │
# │ 117 │ Monaco                           │ 1                     │
# │ 118 │ Mongolia                         │ 1                     │
# │ 119 │ Montenegro                       │ 1                     │
# │ 120 │ Morocco                          │ 1                     │
# │ 121 │ Mozambique                       │ 1                     │
# │ 122 │ Namibia                          │ 1                     │
# │ 123 │ Nepal                            │ 1                     │
# │ 124 │ New Zealand                      │ 1                     │
# │ 125 │ Nicaragua                        │ 1                     │
# │ 126 │ Niger                            │ 1                     │
# │ 127 │ Nigeria                          │ 1                     │
# │ 128 │ North Macedonia                  │ 1                     │
# │ 129 │ Norway                           │ 1                     │
# │ 130 │ Oman                             │ 1                     │
# │ 131 │ Pakistan                         │ 1                     │
# │ 132 │ Panama                           │ 1                     │
# │ 133 │ Papua New Guinea                 │ 1                     │
# │ 134 │ Paraguay                         │ 1                     │
# │ 135 │ Peru                             │ 1                     │
# │ 136 │ Philippines                      │ 1                     │
# │ 137 │ Poland                           │ 1                     │
# │ 138 │ Portugal                         │ 1                     │
# │ 139 │ Qatar                            │ 1                     │
# │ 140 │ Romania                          │ 1                     │
# │ 141 │ Russia                           │ 1                     │
# │ 142 │ Rwanda                           │ 1                     │
# │ 143 │ Saint Kitts and Nevis            │ 1                     │
# │ 144 │ Saint Lucia                      │ 1                     │
# │ 145 │ Saint Vincent and the Grenadines │ 1                     │
# │ 146 │ San Marino                       │ 1                     │
# │ 147 │ Saudi Arabia                     │ 1                     │
# │ 148 │ Senegal                          │ 1                     │
# │ 149 │ Serbia                           │ 1                     │
# │ 150 │ Seychelles                       │ 1                     │
# │ 151 │ Sierra Leone                     │ 1                     │
# │ 152 │ Singapore                        │ 1                     │
# │ 153 │ Slovakia                         │ 1                     │
# │ 154 │ Slovenia                         │ 1                     │
# │ 155 │ Somalia                          │ 1                     │
# │ 156 │ South Africa                     │ 1                     │
# │ 157 │ Spain                            │ 1                     │
# │ 158 │ Sri Lanka                        │ 1                     │
# │ 159 │ Sudan                            │ 1                     │
# │ 160 │ Suriname                         │ 1                     │
# │ 161 │ Sweden                           │ 1                     │
# │ 162 │ Switzerland                      │ 1                     │
# │ 163 │ Syria                            │ 1                     │
# │ 164 │ Taiwan*                          │ 1                     │
# │ 165 │ Tanzania                         │ 1                     │
# │ 166 │ Thailand                         │ 1                     │
# │ 167 │ Timor-Leste                      │ 1                     │
# │ 168 │ Togo                             │ 1                     │
# │ 169 │ Trinidad and Tobago              │ 1                     │
# │ 170 │ Tunisia                          │ 1                     │
# │ 171 │ Turkey                           │ 1                     │
# │ 172 │ Uganda                           │ 1                     │
# │ 173 │ Ukraine                          │ 1                     │
# │ 174 │ United Arab Emirates             │ 1                     │
# │ 175 │ Uruguay                          │ 1                     │
# │ 176 │ Uzbekistan                       │ 1                     │
# │ 177 │ Venezuela                        │ 1                     │
# │ 178 │ Vietnam                          │ 1                     │
# │ 179 │ West Bank and Gaza               │ 1                     │
# │ 180 │ Zambia                           │ 1                     │
# │ 181 │ Zimbabwe                         │ 1                     │
#
# │ Row │ Confirmed_sum │
# │     │ Int64         │
# ├─────┼───────────────┤
# │ 1   │ 243599        │
# │ 2   │ 11284         │
# │ 3   │ 34173         │
# │ 4   │ 82432         │
# │ 5   │ 14788         │
# │ 6   │ 5116          │
# │ 7   │ 3573          │
# │ 8   │ 59929         │
# │ 9   │ 273           │
# │ 10  │ 277           │
# │ 11  │ 986           │
# │ 12  │ 428           │
# │ 13  │ 8             │
# │ 14  │ 9             │
# │ 15  │ 1133          │
# │ 16  │ 663           │
# │ 17  │ 11129         │
# │ 18  │ 400           │
# │ 19  │ 24            │
# │ 20  │ 643           │
# │ 21  │ 56            │
# │ 22  │ 46            │
# │ 23  │ 304           │
# │ 24  │ 15348         │
# │ 25  │ 3             │
# │ 26  │ 13            │
# │ 27  │ 5             │
# │ 28  │ 123           │
# │ 29  │ 533           │
# │ 30  │ 4             │
# │ 31  │ 8044          │
# │ 32  │ 133           │
# │ 33  │ 457           │
# │ 34  │ 288           │
# │ 35  │ 20            │
# │ 36  │ 3             │
# │ 37  │ 6             │
# │ 38  │ 110           │
# │ 39  │ 306           │
# │ 40  │ 3             │
# │ 41  │ 8             │
# │ 42  │ 3404          │
# │ 43  │ 1161          │
# │ 44  │ 22            │
# │ 45  │ 134           │
# │ 46  │ 396           │
# │ 47  │ 194           │
# │ 48  │ 1011          │
# │ 49  │ 233           │
# │ 50  │ 356           │
# │ 51  │ 3858          │
# │ 52  │ 712           │
# │ 53  │ 40            │
# │ 54  │ 12            │
# │ 55  │ 1380          │
# │ 56  │ 3163          │
# │ 57  │ 865           │
# │ 58  │ 41            │
# │ 59  │ 15            │
# │ 60  │ 22            │
# │ 61  │ 858           │
# │ 62  │ 9             │
# │ 63  │ 29            │
# │ 64  │ 7             │
# │ 65  │ 1518          │
# │ 66  │ 21            │
# │ 67  │ 4             │
# │ 68  │ 134           │
# │ 69  │ 84794         │
# │ 70  │ 204           │
# │ 71  │ 1544          │
# │ 72  │ 10            │
# │ 73  │ 47            │
# │ 74  │ 52            │
# │ 75  │ 9             │
# │ 76  │ 19            │
# │ 77  │ 16            │
# │ 78  │ 7             │
# │ 79  │ 219           │
# │ 80  │ 585           │
# │ 81  │ 1319          │
# │ 82  │ 2543          │
# │ 83  │ 1790          │
# │ 84  │ 50468         │
# │ 85  │ 772           │
# │ 86  │ 3849          │
# │ 87  │ 6857          │
# │ 88  │ 115242        │
# │ 89  │ 47            │
# │ 90  │ 2495          │
# │ 91  │ 299           │
# │ 92  │ 435           │
# │ 93  │ 110           │
# │ 94  │ 9976          │
# │ 95  │ 125           │
# │ 96  │ 342           │
# │ 97  │ 116           │
# │ 98  │ 10            │
# │ 99  │ 458           │
# │ 100 │ 494           │
# │ 101 │ 6             │
# │ 102 │ 11            │
# │ 103 │ 75            │
# │ 104 │ 649           │
# │ 105 │ 2487          │
# │ 106 │ 9             │
# │ 107 │ 59            │
# │ 108 │ 3             │
# │ 109 │ 3116          │
# │ 110 │ 19            │
# │ 111 │ 36            │
# │ 112 │ 196           │
# │ 113 │ 6             │
# │ 114 │ 169           │
# │ 115 │ 1378          │
# │ 116 │ 505           │
# │ 117 │ 60            │
# │ 118 │ 14            │
# │ 119 │ 144           │
# │ 120 │ 708           │
# │ 121 │ 10            │
# │ 122 │ 14            │
# │ 123 │ 6             │
# │ 124 │ 797           │
# │ 125 │ 5             │
# │ 126 │ 98            │
# │ 127 │ 184           │
# │ 128 │ 384           │
# │ 129 │ 5147          │
# │ 130 │ 231           │
# │ 131 │ 2421          │
# │ 132 │ 1317          │
# │ 133 │ 1             │
# │ 134 │ 77            │
# │ 135 │ 1414          │
# │ 136 │ 2633          │
# │ 137 │ 2946          │
# │ 138 │ 9034          │
# │ 139 │ 949           │
# │ 140 │ 2738          │
# │ 141 │ 3548          │
# │ 142 │ 84            │
# │ 143 │ 9             │
# │ 144 │ 13            │
# │ 145 │ 2             │
# │ 146 │ 245           │
# │ 147 │ 1885          │
# │ 148 │ 195           │
# │ 149 │ 1171          │
# │ 150 │ 10            │
# │ 151 │ 2             │
# │ 152 │ 1049          │
# │ 153 │ 426           │
# │ 154 │ 897           │
# │ 155 │ 5             │
# │ 156 │ 1462          │
# │ 157 │ 112065        │
# │ 158 │ 151           │
# │ 159 │ 8             │
# │ 160 │ 10            │
# │ 161 │ 5568          │
# │ 162 │ 18827         │
# │ 163 │ 16            │
# │ 164 │ 339           │
# │ 165 │ 20            │
# │ 166 │ 1875          │
# │ 167 │ 1             │
# │ 168 │ 39            │
# │ 169 │ 94            │
# │ 170 │ 455           │
# │ 171 │ 18135         │
# │ 172 │ 45            │
# │ 173 │ 897           │
# │ 174 │ 1024          │
# │ 175 │ 350           │
# │ 176 │ 205           │
# │ 177 │ 146           │
# │ 178 │ 233           │
# │ 179 │ 161           │
# │ 180 │ 39            │
# │ 181 │ 9             │

# %% [markdown]
# ## 作業2：請列出美國各區域或事件 (依 Province_State 欄) 的累積確診、死亡、康復人數。
#
# 【提示】使用 Split-Apply-Combine Strategy 時，有幾種不同的函式可以使用，請參照 `DataFrames.jl` 官方文件 [https://juliadata.github.io/DataFrames.jl/stable/lib/functions/#DataFrames.groupby](https://juliadata.github.io/DataFrames.jl/stable/lib/functions/#DataFrames.groupby)

# %%
df3=df[df.Country_Region .== "US", [:Province_State, :Confirmed, :Deaths, :Recovered]]
# Out:
# 2312×4 DataFrame
# │ Row  │ Province_State           │ Confirmed │ Deaths │ Recovered │
# │      │ Union{Missing, String}   │ Int64     │ Int64  │ Int64     │
# ├──────┼──────────────────────────┼───────────┼────────┼───────────┤
# │ 1    │ South Carolina           │ 6         │ 0      │ 0         │
# │ 2    │ Louisiana                │ 61        │ 1      │ 0         │
# │ 3    │ Virginia                 │ 10        │ 0      │ 0         │
# │ 4    │ Idaho                    │ 312       │ 3      │ 0         │
# │ 5    │ Iowa                     │ 1         │ 0      │ 0         │
# │ 6    │ Missouri                 │ 6         │ 0      │ 0         │
# │ 7    │ Oklahoma                 │ 9         │ 0      │ 0         │
# │ 8    │ Colorado                 │ 212       │ 2      │ 0         │
# │ 9    │ Idaho                    │ 1         │ 0      │ 0         │
# │ 10   │ Illinois                 │ 2         │ 0      │ 0         │
# ⋮
# │ 2302 │ California               │ 8         │ 0      │ 0         │
# │ 2303 │ Arizona                  │ 13        │ 0      │ 0         │
# │ 2304 │ Colorado                 │ 2         │ 0      │ 0         │
# │ 2305 │ Diamond Princess         │ 49        │ 0      │ 0         │
# │ 2306 │ Grand Princess           │ 103       │ 3      │ 0         │
# │ 2307 │ Guam                     │ 82        │ 3      │ 0         │
# │ 2308 │ Northern Mariana Islands │ 6         │ 1      │ 0         │
# │ 2309 │ Puerto Rico              │ 316       │ 12     │ 0         │
# │ 2310 │ Recovered                │ 0         │ 0      │ 9001      │
# │ 2311 │ Virgin Islands           │ 30        │ 0      │ 0         │
# │ 2312 │ Wyoming                  │ 0         │ 0      │ 0         │

# %%
gd = groupby(df3, :Province_State)
# Out:
# GroupedDataFrame with 58 groups based on key: Province_State
# First Group (46 rows): Province_State = "South Carolina"
# │ Row │ Province_State │ Confirmed │ Deaths │ Recovered │
# │     │ String⍰        │ Int64     │ Int64  │ Int64     │
# ├─────┼────────────────┼───────────┼────────┼───────────┤
# │ 1   │ South Carolina │ 6         │ 0      │ 0         │
# │ 2   │ South Carolina │ 22        │ 1      │ 0         │
# │ 3   │ South Carolina │ 1         │ 0      │ 0         │
# │ 4   │ South Carolina │ 57        │ 3      │ 0         │
# │ 5   │ South Carolina │ 5         │ 0      │ 0         │
# │ 6   │ South Carolina │ 2         │ 0      │ 0         │
# │ 7   │ South Carolina │ 130       │ 2      │ 0         │
# │ 8   │ South Carolina │ 33        │ 0      │ 0         │
# │ 9   │ South Carolina │ 3         │ 1      │ 0         │
# │ 10  │ South Carolina │ 231       │ 1      │ 0         │
# ⋮
# │ 36  │ South Carolina │ 4         │ 0      │ 0         │
# │ 37  │ South Carolina │ 5         │ 0      │ 0         │
# │ 38  │ South Carolina │ 24        │ 0      │ 0         │
# │ 39  │ South Carolina │ 15        │ 0      │ 0         │
# │ 40  │ South Carolina │ 200       │ 3      │ 0         │
# │ 41  │ South Carolina │ 2         │ 0      │ 0         │
# │ 42  │ South Carolina │ 50        │ 0      │ 0         │
# │ 43  │ South Carolina │ 66        │ 3      │ 0         │
# │ 44  │ South Carolina │ 5         │ 0      │ 0         │
# │ 45  │ South Carolina │ 6         │ 0      │ 0         │
# │ 46  │ South Carolina │ 66        │ 1      │ 0         │
# ⋮
# Last Group (1 row): Province_State = "Virgin Islands"
# │ Row │ Province_State │ Confirmed │ Deaths │ Recovered │
# │     │ String⍰        │ Int64     │ Int64  │ Int64     │
# ├─────┼────────────────┼───────────┼────────┼───────────┤
# │ 1   │ Virgin Islands │ 30        │ 0      │ 0         │
