# %% [markdown]
# # Julia 基礎圖表繪製: Plots 套件
#
# ## 作業 023：繪製 3D 函數
#
# 練習繪製 3D 函數：$z = x^2 - y^2$，$x$ 範圍於 $-5 \sim 5$，$y$ 範圍於 $-5 \sim 5$ 之間。（請完成以下程式碼）

# %%
using Plots
# Out:
# ┌ Info: Recompiling stale cache file C:\Users\winds\.julia\compiled\v1.2\Plots\ld3vC.ji for Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# └ @ Base loading.jl:1240

# %%
n = 500
x = range(-5., stop=5., length=n)
y = range(-5., stop=5., length=n)
# Out:
# -5.0:0.02004008016032064:5.0

# %%
f(x,y) = x^2 - y^2
# Out:
# f (generic function with 1 method)

# %%
#p = plot()
p = plot(x, y, f, st=:surface)

# %%
savefig(p, "3d_xsqr-zsqr.png")
